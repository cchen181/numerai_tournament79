# %% [markdown]
# Numerai releases 2 datasets to the user:  numerai_training_data.csv and numerai_tournament_data.csv
#
# These .csvs are too large to post. As a workaround, this script enables others to see *samples* of both datasets.
#
# **Note: The training data is used to create, produce, and validate my model. Following validation, the model is run on the tournament data. Details in ___.ipynb**

# %%
##training data
#import libraries
import pandas as pd
import numpy as np

# read data
train = pd.read_csv("./numerai_training_data.csv")
print('TRAINING DATA')
print('Dimensions:')
print(train.shape)
print('Number of rows:')
print(train.shape[0])
print('Number of columns:')
print(train.shape[1])
print('First five rows of training data:')
train.head()
# Out:
# TRAINING DATA
# Dimensions:
# (535713, 54)
# Number of rows:
# 535713
# Number of columns:
# 54
# First five rows of training data:
#                  id   era data_type  feature1  feature2  feature3  feature4  \
# 0  nb5059fbc40534a1  era1     train   0.49282   0.58077   0.48948   0.56762
# 1  nb2bb43f474f2429  era1     train   0.53427   0.72712   0.61895   0.66238
# 2  n1e960207daad44a  era1     train   0.54888   0.46304   0.49582   0.52395
# 3  n5e99b4326e6f463  era1     train   0.64488   0.56167   0.72591   0.52219
# 4  nf454131816e5401  era1     train   0.45235   0.56569   0.54424   0.34145
#
#    feature5  feature6  feature7   ...    feature42  feature43  feature44  \
# 0   0.56107   0.51168   0.47459   ...      0.40333    0.52337    0.60795
# 1   0.47163   0.66996   0.37673   ...      0.46847    0.44557    0.64831
# 2   0.57362   0.46969   0.50229   ...      0.74065    0.41003    0.43230
# 3   0.49311   0.51511   0.45514   ...      0.67751    0.43340    0.67009
# ...

# %%
##tournament data
# read data
tour = pd.read_csv("./numerai_tournament_data.csv")
print('TOURNAMENT DATA')
print('Dimensions:')
print(tour.shape)
print('Number of rows:')
print(tour.shape[0])
print('Number of columns:')
print(tour.shape[1])
print('First five rows of tournament data:')
tour.head()
# Out:
# TOURNAMENT DATA
# Dimensions:
# (348831, 54)
# Number of rows:
# 348831
# Number of columns:
# 54
# First five rows of tournament data:
#                  id    era   data_type  feature1  feature2  feature3  \
# 0  n614950e52f86476  era86  validation   0.73321   0.40769   0.52738
# 1  n8c131af804784b6  era86  validation   0.41095   0.49730   0.57336
# 2  n68cdeacc1d654de  era86  validation   0.53106   0.52798   0.40962
# 3  n59b64bb3be044f0  era86  validation   0.37164   0.34754   0.57658
# 4  nb859519b853849e  era86  validation   0.57009   0.47230   0.55039
#
#    feature4  feature5  feature6  feature7   ...    feature42  feature43  \
# 0   0.62752   0.53157   0.39902   0.60185   ...      0.73091    0.46047
# 1   0.34116   0.60004   0.65085   0.41450   ...      0.61655    0.54469
# 2   0.74406   0.42711   0.65237   0.49803   ...      0.65628    0.45790
# 3   0.39391   0.53413   0.40982   0.49490   ...      0.48189    0.49643
# ...

# %%
percent = (train.shape[0]/(train.shape[0]+tour.shape[0]))*100
print('TOTAL DATA')
print('% of total data, training:') #total = training + tournament
print(percent)
print('% of total data, tournament:')
print(100-percent)
# Out:
# TOTAL DATA
# % of total data, training:
# 60.563748100716296
# % of total data, tournament:
# 39.436251899283704
